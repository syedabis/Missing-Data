# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url = "https://vincentarelbundock.github.io/Rdatasets/csv/Stat2Data/Hawks.csv"
hawks = pd.read_csv(url, index_col=0)

# %%
hawks
# Out:
#      Month  Day  Year CaptureTime ReleaseTime  BandNumber Species Age  Sex  \
# 1        9   19  1992       13:30         NaN   877-76317      RT   I  NaN
# 2        9   22  1992       10:30               877-76318      RT   I  NaN
# 3        9   23  1992       12:45               877-76319      RT   I  NaN
# 4        9   23  1992       10:50               745-49508      CH   I    F
# 5        9   27  1992       11:15              1253-98801      SS   I    F
# ..     ...  ...   ...         ...         ...         ...     ...  ..  ...
# 904     11   18  2003       14:44              1177-04777      RT   I  NaN
# 905     11   19  2003       10:18               803-05985      SS   I    F
# 906     11   19  2003       12:02              1807-53145      RT   I  NaN
# 907     11   20  2003        9:56              1177-04778      RT   I  NaN
# 908     11   20  2003       13:30              1207-53145      RT   A  NaN
#
#       Wing  Weight  Culmen  Hallux  Tail  StandardTail  Tarsus  WingPitFat  \
# 1    385.0   920.0    25.7    30.1   219           NaN     NaN         NaN
# 2    376.0   930.0     NaN     NaN   221           NaN     NaN         NaN
# 3    381.0   990.0    26.7    31.3   235           NaN     NaN         NaN
# 4    265.0   470.0    18.7    23.5   220           NaN     NaN         NaN
# 5    205.0   170.0    12.5    14.3   157           NaN     NaN         NaN
# ..     ...     ...     ...     ...   ...           ...     ...         ...
# 904  380.0  1525.0    26.0    27.6   224         227.0     NaN         NaN
# 905  190.0   175.0    12.7    15.4   150         153.0     NaN         NaN
# 906  360.0   790.0    21.9    27.6   211         215.0     NaN         NaN
# 907  369.0   860.0    25.2    28.0   207         210.0     NaN         NaN
# 908  199.0  1290.0    28.7    32.1   222         226.0     NaN         NaN
#
#      KeelFat  Crop
# 1        NaN   NaN
# 2        NaN   NaN
# 3        NaN   NaN
# 4        NaN   NaN
# 5        NaN   NaN
# ..       ...   ...
# 904      3.0   0.0
# 905      4.0   0.0
# 906      2.0   0.0
# 907      2.0   0.0
# 908      1.0   0.0
#
# [908 rows x 19 columns]

# %%
hawks.isnull().head(5)
# Out:
#    Month    Day   Year  CaptureTime  ReleaseTime  BandNumber  Species    Age  \
# 1  False  False  False        False         True       False    False  False
# 2  False  False  False        False        False       False    False  False
# 3  False  False  False        False        False       False    False  False
# 4  False  False  False        False        False       False    False  False
# 5  False  False  False        False        False       False    False  False
#
#      Sex   Wing  Weight  Culmen  Hallux   Tail  StandardTail  Tarsus  \
# 1   True  False   False   False   False  False          True    True
# 2   True  False   False    True    True  False          True    True
# 3   True  False   False   False   False  False          True    True
# 4  False  False   False   False   False  False          True    True
# 5  False  False   False   False   False  False          True    True
#
#    WingPitFat  KeelFat  Crop
# 1        True     True  True
# 2        True     True  True
# 3        True     True  True
# 4        True     True  True
# 5        True     True  True

# %%
hawks.drop(['BandNumber', 'StandardTail'], axis=1)
# Out:
#      Month  Day  Year CaptureTime ReleaseTime Species Age  Sex   Wing  Weight  \
# 1        9   19  1992       13:30         NaN      RT   I  NaN  385.0   920.0
# 2        9   22  1992       10:30                  RT   I  NaN  376.0   930.0
# 3        9   23  1992       12:45                  RT   I  NaN  381.0   990.0
# 4        9   23  1992       10:50                  CH   I    F  265.0   470.0
# 5        9   27  1992       11:15                  SS   I    F  205.0   170.0
# ..     ...  ...   ...         ...         ...     ...  ..  ...    ...     ...
# 904     11   18  2003       14:44                  RT   I  NaN  380.0  1525.0
# 905     11   19  2003       10:18                  SS   I    F  190.0   175.0
# 906     11   19  2003       12:02                  RT   I  NaN  360.0   790.0
# 907     11   20  2003        9:56                  RT   I  NaN  369.0   860.0
# 908     11   20  2003       13:30                  RT   A  NaN  199.0  1290.0
#
#      Culmen  Hallux  Tail  Tarsus  WingPitFat  KeelFat  Crop
# 1      25.7    30.1   219     NaN         NaN      NaN   NaN
# 2       NaN     NaN   221     NaN         NaN      NaN   NaN
# 3      26.7    31.3   235     NaN         NaN      NaN   NaN
# 4      18.7    23.5   220     NaN         NaN      NaN   NaN
# 5      12.5    14.3   157     NaN         NaN      NaN   NaN
# ..      ...     ...   ...     ...         ...      ...   ...
# 904    26.0    27.6   224     NaN         NaN      3.0   0.0
# 905    12.7    15.4   150     NaN         NaN      4.0   0.0
# 906    21.9    27.6   211     NaN         NaN      2.0   0.0
# 907    25.2    28.0   207     NaN         NaN      2.0   0.0
# 908    28.7    32.1   222     NaN         NaN      1.0   0.0
#
# [908 rows x 17 columns]

# %%
hawks.drop(['ReleaseTime', 'CaptureTime','BandNumber', 'StandardTail'], axis=1).isnull().head(20)
# Out:
#     Month    Day   Year  Species    Age    Sex   Wing  Weight  Culmen  Hallux  \
# 1   False  False  False    False  False   True  False   False   False   False
# 2   False  False  False    False  False   True  False   False    True    True
# 3   False  False  False    False  False   True  False   False   False   False
# 4   False  False  False    False  False  False  False   False   False   False
# 5   False  False  False    False  False  False  False   False   False   False
# 6   False  False  False    False  False   True  False   False   False   False
# 7   False  False  False    False  False   True  False   False   False   False
# 8   False  False  False    False  False   True  False   False   False   False
# 9   False  False  False    False  False   True  False   False   False   False
# 10  False  False  False    False  False   True  False   False   False   False
# 11  False  False  False    False  False   True  False   False   False   False
# 12  False  False  False    False  False   True  False   False   False   False
# 13  False  False  False    False  False   True  False   False   False   False
# 14  False  False  False    False  False   True  False    True   False   False
# 15  False  False  False    False  False   True  False   False   False   False
# 16  False  False  False    False  False   True  False   False   False   False
# 17  False  False  False    False  False   True  False   False   False   False
# 18  False  False  False    False  False   True  False   False   False   False
# 19  False  False  False    False  False   True  False   False   False   False
# 20  False  False  False    False  False   True  False   False   False   False
#
#      Tail  Tarsus  WingPitFat  KeelFat  Crop
# 1   False    True        True     True  True
# 2   False    True        True     True  True
# 3   False    True        True     True  True
# 4   False    True        True     True  True
# 5   False    True        True     True  True
# 6   False    True        True     True  True
# 7   False    True        True     True  True
# 8   False    True        True     True  True
# 9   False    True        True     True  True
# 10  False    True        True     True  True
# 11  False    True        True     True  True
# 12  False    True        True     True  True
# 13  False    True        True     True  True
# 14  False    True        True     True  True
# 15  False    True        True     True  True
# 16  False    True        True     True  True
# 17  False    True        True     True  True
# 18  False    True        True     True  True
# 19  False    True        True     True  True
# 20  False    True        True     True  True

# %%
plt.figure(figsize=(10,6))
sns.displot(
    data=hawks.isna().melt(value_name="missing"),
    y="variable",
    hue="missing",
    multiple="fill",
    aspect=1.4
    
)
plt.savefig("visualizing_missing_data_with_barplot_Seaborn_distplot.png", dpi=100)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(hawks.isna().transpose(),
            cmap="GnBu",
            cbar_kws={'label': 'Missing Data'})
plt.savefig("visualizing_missing_data_with_heatmap_Seaborn_Python.png", dpi=100)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(hawks.isna().transpose(),
            cmap="viridis",
            cbar_kws={'label': 'Missing Data'})
plt.savefig("visualizing_missing_data_with_heatmap_Seaborn_Python.png", dpi=100)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(hawks.isna().transpose(),
            cmap="cividis",
            cbar_kws={'label': 'Missing Data'})
plt.savefig("visualizing_missing_data_with_heatmap_Seaborn_Python.png", dpi=100)
